# %%
import util
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

image = np.asarray(Image.open("/home/jonda/Downloads/high_res.jpeg"))
image2 = Image.open("/home/jonda/Downloads/high_res.jpeg")
patches = util.patchify(image)
# util.makePlot([patches[5][0], patches[5][1]])
for patch in patches[0]:
    print(patch.shape)
    plt.imshow(patch)
# unpatched = util.unpatchify(patches)

# plt.imshow(unpatched)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
